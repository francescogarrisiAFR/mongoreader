# %%
import mongomanager as mom
from mongoutils import queryUtils as qu
from mongomanager.goggleFunctions import componentGoggleFunctions as cmpGGF
conn = mom.connection('R&D', 'Francesco')
# Out:
# Password retrieved from keyring.
# (R&D) mongodb://francesco:********@10.201.21.36:27017

# %%
import mongoreader.wafers as morw

# %%
wc = morw.waferCollation(conn, '3CA0027')
chip = wc.chipsDict['COR-V1-03']
bp = wc.chipBPdict['COR-V1-03']
# Out:
# Collected wafer "3CA0027"
# Collected wafer blueprint "Cordoba wafer".
# Collected 3 chipBlueprints.
# Collected 2 testChipBlueprints.
# Collected 6 barBlueprints.
#  WARNING  :: Could not retrieve any testCellBlueprints.
# Collected 60 chips.
# Collected 30 test chips.
# Collected 6 bars.

# %%
chip.Datasheet.createDatasheet(conn, useTestReports=True)
# Out:
#  WARNING  :: Instanciated blueprint, but "type" field is "opticalChipBlueprint".
# Total results: 1
# Total results: 2
#  WARNING  :: Instanciated blueprint, but "type" field is "opticalChipBlueprint".
# {'evaluationDate': datetime.datetime(2024, 2, 2, 14, 12, 5, 404233, tzinfo=<UTC>),
#  'datasheetEvaluationMethodID': None,
#  'data': [{'resultName': 'IL',
#    'location': 'device',
#    'requiredTags': ['1550nm', '25C'],
#    'tagsToExclude': None,
#    'resultData': {'value': 6.648599000000003, 'error': 0.4, 'unit': 'dB'},
#    'executionDate': datetime.datetime(2023, 10, 14, 6, 3, 20, 79000, tzinfo=<UTC>),
#    'testReportID': None,
#    'testHistoryIndex': 0,
#    'testResultsIndex': 13},
#   {'resultName': 'IL',
#    'location': 'external loop',
#    'requiredTags': ['1550nm', '25C'],
#    'tagsToExclude': None,
#    'resultData': {'value': 4.112534599999999, 'error': 0.4, 'unit': 'dB'},
#    'executionDate': datetime.datetime(2023, 10, 14, 6, 3, 20, 79000, tzinfo=<UTC>),
# ...
